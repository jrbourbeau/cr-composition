# %%
import sys
sys.path.append('/home/jbourbeau/cr-composition')
print('Added to PYTHONPATH')
# Out:
# Added to PYTHONPATH

# %%
import argparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn.apionly as sns

from sklearn.metrics import accuracy_score
from sklearn.model_selection import validation_curve, GridSearchCV, cross_val_score, ParameterGrid

import composition as comp
import composition.analysis.plotting as plotting

# %matplotlib inline
sns.set_palette('muted')
sns.set_color_codes()
# Out:
# /home/jbourbeau/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# 1. Load simulation dataframe and apply specified quality cuts
# 2. Extract desired features from dataframe
# 3. Get separate testing and training datasets

# %%
df, cut_dict = comp.load_sim(return_cut_dict=True)
selection_mask = np.array([True] * len(df))
standard_cut_keys = ['lap_reco_success', 'lap_zenith', 'num_hits_45_60', 'IT_signal',
                     'StationDensity', 'max_qfrac_45_60', 'lap_containment', 'energy_range_lap']
# standard_cut_keys = ['lap_reco_success', 'lap_zenith', 'num_hits_1_30', 'IT_signal',
#                      'StationDensity', 'max_qfrac_1_30', 'lap_containment', 'energy_range_lap']
# standard_cut_keys = ['reco_exists', 'reco_zenith', 'num_hits_1_60', 'IT_signal',
#                      'StationDensity', 'max_qfrac_1_60', 'reco_containment', 'energy_range']
for key in standard_cut_keys:
    selection_mask *= cut_dict[key]

df = df[selection_mask]

feature_list, feature_labels = comp.get_training_features()
print('training features = {}'.format(feature_list))
X_train, X_test, y_train, y_test, le = comp.get_train_test_sets(
    df, feature_list, train_he=True, test_he=True)

print('number training events = ' + str(y_train.shape[0]))
# Out:
# /home/jbourbeau/cr-composition/composition/load_sim.py:109: RuntimeWarning: divide by zero encountered in log10
#   df['log_NChannels_1_30'] = np.nan_to_num(np.log10(df['NChannels_1_30']))
# training features = ['lap_log_energy', 'InIce_log_charge_1_30', 'lap_cos_zenith', 'NChannels_1_30', 'log_s125']
# number training events = 82408

# %%
X_train[:50, 0], le.inverse_transform(y_train)[:50], le.inverse_transform(y_test)[:50]
# Out:
# (array([ 6.44662778,  7.86627784,  6.59962503,  6.82091424,  7.60676344,
#          6.21448064,  6.48497238,  6.85217622,  7.56594326,  6.41748673,
#          7.69858618,  7.22671799,  6.5288059 ,  6.51230536,  7.14926385,
#          7.63684919,  7.14332047,  7.31713482,  7.06631171,  7.8943434 ,
#          6.81265567,  6.68914717,  7.94058341,  6.58938898,  6.40761168,
#          7.33456581,  7.66660701,  6.81142229,  6.89427767,  7.56391569,
#          7.86560961,  7.63907239,  7.92735224,  6.5382236 ,  7.89726147,
#          7.43687611,  6.9827456 ,  7.69661523,  6.4335847 ,  6.9182418 ,
#          6.5067947 ,  6.84084176,  6.77788941,  6.98240114,  6.59656763,
#          6.28196335,  7.75507639,  6.76567171,  6.40263978,  6.31080251]),
#  array(['Fe', 'Fe', 'He', 'He', 'He', 'Fe', 'P', 'He', 'He', 'P', 'P', 'Fe',
#         'P', 'Fe', 'P', 'Fe', 'P', 'He', 'He', 'He', 'Fe', 'He', 'He', 'He',
#         'He', 'P', 'P', 'Fe', 'He', 'P', 'He', 'He', 'Fe', 'Fe', 'Fe', 'P',
#         'Fe', 'He', 'He', 'He', 'P', 'He', 'He', 'Fe', 'P', 'Fe', 'P', 'P',
#         'P', 'Fe'], dtype=object),
#  array(['He', 'Fe', 'He', 'Fe', 'P', 'Fe', 'P', 'P', 'He', 'Fe', 'P', 'P',
#         'P', 'P', 'P', 'He', 'Fe', 'He', 'Fe', 'He', 'He', 'He', 'Fe', 'He',
#         'P', 'He', 'He', 'He', 'He', 'Fe', 'He', 'Fe', 'P', 'He', 'Fe',
#         'Fe', 'Fe', 'Fe', 'P', 'Fe', 'P', 'He', 'P', 'P', 'He', 'Fe', 'P',
#         'He', 'He', 'Fe'], dtype=object))

# %% [markdown]
# Get error in charge vs. energy distribution

# %%
len(df)
# Out:
# 117727

# %%
pipeline = comp.get_pipeline('RF')
param_range = np.arange(1, 31)
param_grid = {'classifier__max_depth': param_range}
gs = GridSearchCV(estimator=pipeline,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=5,
                  verbose=1,
                  n_jobs=20)
gs = gs.fit(X_train, y_train)
print('best GS CV score = {}'.format(gs.best_score_))
print('best GS CV depths = {}'.format(gs.best_params_))
print('Grid scores on development set:')
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gs.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
pipeline.set_params(**gs.best_params_)
pipeline.fit(X_train, y_train)
scaler = pipeline.named_steps['scaler']
clf = pipeline.named_steps['classifier']
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=20)]: Done 150 out of 150 | elapsed:  2.0min finished
# best GS CV score = 0.600572759926
# best GS CV depths = {'classifier__max_depth': 13}
# Grid scores on development set:
# 0.441 (+/-0.004) for {'classifier__max_depth': 1}
# 0.456 (+/-0.007) for {'classifier__max_depth': 2}
# 0.515 (+/-0.015) for {'classifier__max_depth': 3}
# 0.544 (+/-0.013) for {'classifier__max_depth': 4}
# 0.573 (+/-0.008) for {'classifier__max_depth': 5}
# 0.585 (+/-0.008) for {'classifier__max_depth': 6}
# 0.591 (+/-0.007) for {'classifier__max_depth': 7}
# 0.595 (+/-0.009) for {'classifier__max_depth': 8}
# 0.597 (+/-0.007) for {'classifier__max_depth': 9}
# 0.599 (+/-0.010) for {'classifier__max_depth': 10}
# 0.601 (+/-0.009) for {'classifier__max_depth': 11}
# 0.600 (+/-0.009) for {'classifier__max_depth': 12}
# 0.601 (+/-0.008) for {'classifier__max_depth': 13}
# 0.600 (+/-0.007) for {'classifier__max_depth': 14}
# 0.600 (+/-0.007) for {'classifier__max_depth': 15}
# 0.599 (+/-0.007) for {'classifier__max_depth': 16}
# 0.599 (+/-0.008) for {'classifier__max_depth': 17}
# 0.598 (+/-0.007) for {'classifier__max_depth': 18}
# 0.598 (+/-0.007) for {'classifier__max_depth': 19}
# 0.598 (+/-0.007) for {'classifier__max_depth': 20}
# 0.598 (+/-0.008) for {'classifier__max_depth': 21}
# 0.598 (+/-0.008) for {'classifier__max_depth': 22}
# 0.597 (+/-0.005) for {'classifier__max_depth': 23}
# 0.597 (+/-0.009) for {'classifier__max_depth': 24}
# 0.598 (+/-0.006) for {'classifier__max_depth': 25}
# 0.597 (+/-0.006) for {'classifier__max_depth': 26}
# 0.597 (+/-0.006) for {'classifier__max_depth': 27}
# 0.597 (+/-0.008) for {'classifier__max_depth': 28}
# 0.597 (+/-0.008) for {'classifier__max_depth': 29}
# 0.597 (+/-0.008) for {'classifier__max_depth': 30}

# %%
clf_name = clf.__class__.__name__
print('=' * 30)
print(clf_name)
test_predictions = pipeline.predict(X_test)
test_acc = accuracy_score(y_test, test_predictions)
print('Test accuracy: {:.4%}'.format(test_acc))
train_predictions = pipeline.predict(X_train)
train_acc = accuracy_score(y_train, train_predictions)
print('Train accuracy: {:.4%}'.format(train_acc))
scores = cross_val_score(
    estimator=pipeline, X=X_test, y=y_test, cv=10, n_jobs=10)
print('CV score: {:.2%} (+/- {:.2%})'.format(scores.mean(), scores.std()))
print('=' * 30)
# Out:
# ==============================
# RandomForestClassifier
# Test accuracy: 60.1263%
# Train accuracy: 68.0723%
# CV score: 59.52% (+/- 0.96%)
# ==============================

# %%
wah = clf.estimators_

# %%
decisiontree = clf.estimators_[0]
tree =  decisiontree.tree_
# print(tree.decision_path(X_test.astype(np.float32)))
print(tree.node_count)
print(tree.n_node_samples)
print(tree.apply(X_test.astype(np.float32)))
print(tree.n_node_samples[tree.apply(X_test.astype(np.float32))])
print(tree.children_left)
leaf_samples = []
for tree in clf.estimators_:
    leaf_samples.extend(tree.tree_.n_node_samples[tree.apply(X_test.astype(np.float32))])
print(np.min(leaf_samples))
print(np.max(leaf_samples))
# Out:
# 3331
# [51993  9995  2436 ...,    96    60    17]
# [3330 3330 3330 ..., 3330 3330 3330]
# [17 17 17 ..., 17 17 17]
# [ 1  2  3 ..., -1 -1 -1]
# 10
# 376

# %%
counts, bins, pathches = plt.hist(leaf_samples, bins=np.linspace(0, 200, 100), log=True)

# %%
# Using those arrays, we can parse the tree structure:
estimator = clf.estimators_[0]
n_nodes = estimator.tree_.node_count
children_left = estimator.tree_.children_left
children_right = estimator.tree_.children_right
feature = estimator.tree_.feature
threshold = estimator.tree_.threshold


# The tree structure can be traversed to compute various properties such
# as the depth of each node and whether or not it is a leaf.
node_depth = np.zeros(shape=n_nodes)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, -1)]  # seed is the root node id and its parent depth
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1

    # If we have a test node
    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True

print("The binary tree structure has %s nodes and has "
      "the following tree structure:"
      % n_nodes)
for i in range(n_nodes):
    if is_leaves[i]:
        print("%snode=%s leaf node." % ("\t", i))
#         print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
#     else:
#         print("%snode=%s test node: go to node %s if X[:, %s] <= %ss else to "
#               "node %s."
#               % (node_depth[i] * "\t",
#                  i,
#                  children_left[i],
#                  feature[i],
#                  threshold[i],
#                  children_right[i],
#                  ))
print()
# Out:
# The binary tree structure has 2933 nodes and has the following tree structure:
# 	node=10 leaf node.
# 	node=11 leaf node.
# 	node=13 leaf node.
# 	node=16 leaf node.
# 	node=17 leaf node.
# 	node=19 leaf node.
# 	node=20 leaf node.
# 	node=23 leaf node.
# 	node=25 leaf node.
# 	node=26 leaf node.
# 	node=29 leaf node.
# 	node=31 leaf node.
# 	node=32 leaf node.
# 	node=35 leaf node.
# 	node=36 leaf node.
# 	node=38 leaf node.
# 	node=39 leaf node.
# 	node=43 leaf node.
# 	node=45 leaf node.
# 	node=47 leaf node.
# 	node=48 leaf node.
# 	node=51 leaf node.
# 	node=52 leaf node.
# 	node=53 leaf node.
# 	node=57 leaf node.
# 	node=58 leaf node.
# 	node=60 leaf node.
# 	node=62 leaf node.
# 	node=63 leaf node.
# 	node=66 leaf node.
# 	node=67 leaf node.
# 	node=69 leaf node.
# 	node=70 leaf node.
# 	node=75 leaf node.
# 	node=78 leaf node.
# 	node=79 leaf node.
# 	node=81 leaf node.
# 	node=82 leaf node.
# 	node=85 leaf node.
# 	node=87 leaf node.
# 	node=88 leaf node.
# 	node=91 leaf node.
# 	node=92 leaf node.
# 	node=94 leaf node.
# 	node=95 leaf node.
# 	node=100 leaf node.
# 	node=101 leaf node.
# 	node=103 leaf node.
# 	node=104 leaf node.
# 	node=107 leaf node.
# 	node=108 leaf node.
# 	node=110 leaf node.
# 	node=111 leaf node.
# 	node=113 leaf node.
# 	node=115 leaf node.
# 	node=117 leaf node.
# 	node=118 leaf node.
# 	node=124 leaf node.
# 	node=125 leaf node.
# 	node=126 leaf node.
# 	node=129 leaf node.
# 	node=130 leaf node.
# 	node=131 leaf node.
# 	node=135 leaf node.
# 	node=136 leaf node.
# 	node=138 leaf node.
# 	node=139 leaf node.
# 	node=140 leaf node.
# 	node=145 leaf node.
# 	node=146 leaf node.
# 	node=148 leaf node.
# 	node=149 leaf node.
# 	node=151 leaf node.
# 	node=153 leaf node.
# 	node=154 leaf node.
# 	node=158 leaf node.
# 	node=159 leaf node.
# 	node=161 leaf node.
# 	node=162 leaf node.
# 	node=164 leaf node.
# 	node=166 leaf node.
# 	node=167 leaf node.
# 	node=175 leaf node.
# 	node=176 leaf node.
# 	node=178 leaf node.
# 	node=179 leaf node.
# 	node=181 leaf node.
# 	node=183 leaf node.
# 	node=184 leaf node.
# 	node=187 leaf node.
# 	node=189 leaf node.
# 	node=190 leaf node.
# 	node=191 leaf node.
# 	node=194 leaf node.
# 	node=197 leaf node.
# 	node=198 leaf node.
# 	node=200 leaf node.
# 	node=201 leaf node.
# 	node=205 leaf node.
# 	node=206 leaf node.
# 	node=208 leaf node.
# 	node=209 leaf node.
# 	node=212 leaf node.
# 	node=213 leaf node.
# 	node=214 leaf node.
# 	node=218 leaf node.
# 	node=221 leaf node.
# 	node=222 leaf node.
# 	node=223 leaf node.
# 	node=224 leaf node.
# 	node=229 leaf node.
# 	node=230 leaf node.
# 	node=232 leaf node.
# 	node=233 leaf node.
# 	node=236 leaf node.
# 	node=237 leaf node.
# 	node=238 leaf node.
# 	node=240 leaf node.
# 	node=243 leaf node.
# 	node=244 leaf node.
# 	node=246 leaf node.
# 	node=247 leaf node.
# 	node=254 leaf node.
# 	node=255 leaf node.
# 	node=257 leaf node.
# 	node=258 leaf node.
# 	node=261 leaf node.
# 	node=262 leaf node.
# 	node=264 leaf node.
# 	node=265 leaf node.
# 	node=269 leaf node.
# 	node=270 leaf node.
# 	node=272 leaf node.
# 	node=273 leaf node.
# 	node=276 leaf node.
# 	node=277 leaf node.
# 	node=279 leaf node.
# 	node=280 leaf node.
# 	node=283 leaf node.
# 	node=284 leaf node.
# 	node=288 leaf node.
# 	node=289 leaf node.
# 	node=291 leaf node.
# 	node=292 leaf node.
# 	node=295 leaf node.
# 	node=296 leaf node.
# 	node=298 leaf node.
# 	node=299 leaf node.
# 	node=305 leaf node.
# 	node=306 leaf node.
# 	node=308 leaf node.
# 	node=309 leaf node.
# 	node=311 leaf node.
# 	node=313 leaf node.
# 	node=314 leaf node.
# 	node=318 leaf node.
# 	node=319 leaf node.
# 	node=321 leaf node.
# 	node=322 leaf node.
# 	node=325 leaf node.
# 	node=326 leaf node.
# 	node=328 leaf node.
# 	node=329 leaf node.
# 	node=334 leaf node.
# 	node=335 leaf node.
# 	node=336 leaf node.
# 	node=339 leaf node.
# 	node=340 leaf node.
# 	node=342 leaf node.
# 	node=343 leaf node.
# 	node=347 leaf node.
# 	node=348 leaf node.
# 	node=350 leaf node.
# 	node=351 leaf node.
# 	node=354 leaf node.
# 	node=355 leaf node.
# 	node=357 leaf node.
# 	node=358 leaf node.
# 	node=364 leaf node.
# 	node=368 leaf node.
# 	node=369 leaf node.
# 	node=371 leaf node.
# 	node=372 leaf node.
# 	node=374 leaf node.
# 	node=375 leaf node.
# 	node=378 leaf node.
# 	node=380 leaf node.
# 	node=382 leaf node.
# 	node=383 leaf node.
# 	node=386 leaf node.
# 	node=387 leaf node.
# 	node=388 leaf node.
# 	node=393 leaf node.
# 	node=395 leaf node.
# 	node=396 leaf node.
# 	node=397 leaf node.
# 	node=401 leaf node.
# 	node=402 leaf node.
# 	node=404 leaf node.
# 	node=405 leaf node.
# 	node=408 leaf node.
# 	node=409 leaf node.
# 	node=410 leaf node.
# 	node=415 leaf node.
# 	node=416 leaf node.
# 	node=418 leaf node.
# 	node=419 leaf node.
# 	node=421 leaf node.
# 	node=423 leaf node.
# 	node=424 leaf node.
# 	node=428 leaf node.
# 	node=429 leaf node.
# 	node=431 leaf node.
# 	node=432 leaf node.
# 	node=435 leaf node.
# 	node=436 leaf node.
# 	node=438 leaf node.
# 	node=439 leaf node.
# 	node=445 leaf node.
# 	node=447 leaf node.
# 	node=448 leaf node.
# 	node=451 leaf node.
# 	node=452 leaf node.
# 	node=454 leaf node.
# 	node=455 leaf node.
# 	node=457 leaf node.
# 	node=460 leaf node.
# 	node=461 leaf node.
# 	node=462 leaf node.
# 	node=465 leaf node.
# 	node=468 leaf node.
# 	node=469 leaf node.
# 	node=471 leaf node.
# 	node=472 leaf node.
# 	node=476 leaf node.
# 	node=477 leaf node.
# 	node=479 leaf node.
# 	node=480 leaf node.
# 	node=482 leaf node.
# 	node=484 leaf node.
# 	node=485 leaf node.
# 	node=488 leaf node.
# 	node=489 leaf node.
# 	node=494 leaf node.
# 	node=495 leaf node.
# 	node=497 leaf node.
# 	node=498 leaf node.
# 	node=499 leaf node.
# 	node=502 leaf node.
# 	node=504 leaf node.
# 	node=505 leaf node.
# 	node=506 leaf node.
# 	node=514 leaf node.
# 	node=515 leaf node.
# 	node=516 leaf node.
# 	node=517 leaf node.
# 	node=521 leaf node.
# 	node=522 leaf node.
# 	node=523 leaf node.
# 	node=524 leaf node.
# 	node=526 leaf node.
# 	node=530 leaf node.
# 	node=531 leaf node.
# 	node=533 leaf node.
# 	node=534 leaf node.
# 	node=537 leaf node.
# 	node=538 leaf node.
# 	node=540 leaf node.
# 	node=541 leaf node.
# 	node=546 leaf node.
# 	node=547 leaf node.
# 	node=549 leaf node.
# 	node=550 leaf node.
# 	node=552 leaf node.
# 	node=553 leaf node.
# 	node=558 leaf node.
# 	node=559 leaf node.
# 	node=560 leaf node.
# 	node=561 leaf node.
# 	node=565 leaf node.
# 	node=566 leaf node.
# 	node=567 leaf node.
# 	node=570 leaf node.
# 	node=571 leaf node.
# 	node=573 leaf node.
# 	node=574 leaf node.
# 	node=578 leaf node.
# 	node=581 leaf node.
# 	node=583 leaf node.
# 	node=584 leaf node.
# 	node=587 leaf node.
# 	node=588 leaf node.
# 	node=590 leaf node.
# 	node=591 leaf node.
# 	node=596 leaf node.
# 	node=597 leaf node.
# 	node=599 leaf node.
# 	node=600 leaf node.
# 	node=602 leaf node.
# 	node=604 leaf node.
# 	node=605 leaf node.
# 	node=609 leaf node.
# 	node=610 leaf node.
# 	node=612 leaf node.
# 	node=613 leaf node.
# 	node=614 leaf node.
# 	node=620 leaf node.
# 	node=621 leaf node.
# 	node=623 leaf node.
# 	node=624 leaf node.
# 	node=627 leaf node.
# 	node=628 leaf node.
# 	node=630 leaf node.
# 	node=631 leaf node.
# 	node=635 leaf node.
# 	node=636 leaf node.
# 	node=638 leaf node.
# 	node=639 leaf node.
# 	node=642 leaf node.
# 	node=643 leaf node.
# 	node=645 leaf node.
# 	node=646 leaf node.
# 	node=651 leaf node.
# 	node=652 leaf node.
# 	node=653 leaf node.
# 	node=656 leaf node.
# 	node=657 leaf node.
# 	node=659 leaf node.
# 	node=660 leaf node.
# 	node=664 leaf node.
# 	node=665 leaf node.
# 	node=666 leaf node.
# 	node=668 leaf node.
# 	node=669 leaf node.
# 	node=676 leaf node.
# 	node=678 leaf node.
# 	node=681 leaf node.
# 	node=682 leaf node.
# 	node=683 leaf node.
# 	node=687 leaf node.
# 	node=689 leaf node.
# 	node=690 leaf node.
# 	node=693 leaf node.
# 	node=694 leaf node.
# 	node=696 leaf node.
# 	node=697 leaf node.
# 	node=701 leaf node.
# 	node=702 leaf node.
# 	node=703 leaf node.
# 	node=706 leaf node.
# 	node=707 leaf node.
# 	node=709 leaf node.
# 	node=710 leaf node.
# 	node=716 leaf node.
# 	node=717 leaf node.
# 	node=719 leaf node.
# 	node=720 leaf node.
# 	node=723 leaf node.
# 	node=724 leaf node.
# 	node=726 leaf node.
# 	node=727 leaf node.
# 	node=730 leaf node.
# 	node=731 leaf node.
# 	node=732 leaf node.
# 	node=736 leaf node.
# 	node=737 leaf node.
# 	node=738 leaf node.
# 	node=742 leaf node.
# 	node=743 leaf node.
# 	node=744 leaf node.
# 	node=746 leaf node.
# 	node=747 leaf node.
# 	node=751 leaf node.
# 	node=754 leaf node.
# 	node=756 leaf node.
# 	node=757 leaf node.
# 	node=760 leaf node.
# 	node=761 leaf node.
# 	node=763 leaf node.
# 	node=764 leaf node.
# 	node=767 leaf node.
# 	node=768 leaf node.
# 	node=771 leaf node.
# 	node=773 leaf node.
# 	node=774 leaf node.
# 	node=777 leaf node.
# 	node=778 leaf node.
# 	node=780 leaf node.
# 	node=781 leaf node.
# 	node=785 leaf node.
# 	node=788 leaf node.
# 	node=789 leaf node.
# 	node=790 leaf node.
# 	node=793 leaf node.
# 	node=795 leaf node.
# 	node=796 leaf node.
# 	node=797 leaf node.
# 	node=800 leaf node.
# 	node=802 leaf node.
# 	node=804 leaf node.
# 	node=805 leaf node.
# 	node=808 leaf node.
# 	node=810 leaf node.
# 	node=811 leaf node.
# 	node=813 leaf node.
# 	node=815 leaf node.
# 	node=816 leaf node.
# 	node=824 leaf node.
# 	node=825 leaf node.
# 	node=826 leaf node.
# 	node=829 leaf node.
# 	node=830 leaf node.
# 	node=832 leaf node.
# 	node=833 leaf node.
# 	node=837 leaf node.
# 	node=838 leaf node.
# 	node=840 leaf node.
# 	node=841 leaf node.
# 	node=844 leaf node.
# 	node=845 leaf node.
# 	node=847 leaf node.
# 	node=848 leaf node.
# 	node=852 leaf node.
# 	node=853 leaf node.
# 	node=856 leaf node.
# 	node=857 leaf node.
# 	node=858 leaf node.
# 	node=862 leaf node.
# 	node=863 leaf node.
# 	node=865 leaf node.
# 	node=866 leaf node.
# 	node=869 leaf node.
# 	node=870 leaf node.
# 	node=872 leaf node.
# 	node=873 leaf node.
# 	node=879 leaf node.
# 	node=880 leaf node.
# 	node=882 leaf node.
# 	node=883 leaf node.
# 	node=885 leaf node.
# 	node=887 leaf node.
# 	node=888 leaf node.
# 	node=890 leaf node.
# 	node=893 leaf node.
# 	node=894 leaf node.
# 	node=895 leaf node.
# 	node=900 leaf node.
# 	node=901 leaf node.
# 	node=903 leaf node.
# 	node=904 leaf node.
# 	node=906 leaf node.
# 	node=907 leaf node.
# 	node=911 leaf node.
# 	node=912 leaf node.
# 	node=914 leaf node.
# 	node=915 leaf node.
# 	node=918 leaf node.
# 	node=919 leaf node.
# 	node=921 leaf node.
# 	node=922 leaf node.
# 	node=928 leaf node.
# 	node=930 leaf node.
# 	node=931 leaf node.
# 	node=933 leaf node.
# 	node=935 leaf node.
# 	node=936 leaf node.
# 	node=940 leaf node.
# 	node=941 leaf node.
# 	node=942 leaf node.
# 	node=944 leaf node.
# 	node=945 leaf node.
# 	node=948 leaf node.
# 	node=949 leaf node.
# 	node=952 leaf node.
# 	node=953 leaf node.
# 	node=954 leaf node.
# 	node=960 leaf node.
# 	node=961 leaf node.
# 	node=963 leaf node.
# 	node=964 leaf node.
# 	node=967 leaf node.
# 	node=968 leaf node.
# 	node=969 leaf node.
# 	node=973 leaf node.
# 	node=974 leaf node.
# 	node=976 leaf node.
# 	node=977 leaf node.
# 	node=978 leaf node.
# 	node=981 leaf node.
# 	node=983 leaf node.
# 	node=984 leaf node.
# 	node=988 leaf node.
# 	node=989 leaf node.
# 	node=990 leaf node.
# 	node=993 leaf node.
# 	node=994 leaf node.
# 	node=996 leaf node.
# 	node=997 leaf node.
# 	node=1006 leaf node.
# 	node=1007 leaf node.
# 	node=1009 leaf node.
# 	node=1010 leaf node.
# 	node=1013 leaf node.
# 	node=1014 leaf node.
# 	node=1016 leaf node.
# 	node=1017 leaf node.
# 	node=1019 leaf node.
# 	node=1020 leaf node.
# 	node=1025 leaf node.
# 	node=1026 leaf node.
# 	node=1027 leaf node.
# 	node=1029 leaf node.
# 	node=1030 leaf node.
# 	node=1034 leaf node.
# 	node=1035 leaf node.
# 	node=1036 leaf node.
# 	node=1039 leaf node.
# 	node=1040 leaf node.
# 	node=1042 leaf node.
# 	node=1043 leaf node.
# 	node=1048 leaf node.
# 	node=1050 leaf node.
# 	node=1051 leaf node.
# 	node=1054 leaf node.
# 	node=1055 leaf node.
# 	node=1057 leaf node.
# 	node=1058 leaf node.
# 	node=1062 leaf node.
# 	node=1063 leaf node.
# 	node=1064 leaf node.
# 	node=1067 leaf node.
# 	node=1068 leaf node.
# 	node=1069 leaf node.
# 	node=1074 leaf node.
# 	node=1075 leaf node.
# 	node=1077 leaf node.
# 	node=1078 leaf node.
# 	node=1080 leaf node.
# 	node=1082 leaf node.
# 	node=1083 leaf node.
# 	node=1087 leaf node.
# 	node=1088 leaf node.
# 	node=1090 leaf node.
# 	node=1091 leaf node.
# 	node=1094 leaf node.
# 	node=1095 leaf node.
# 	node=1097 leaf node.
# 	node=1098 leaf node.
# 	node=1103 leaf node.
# 	node=1106 leaf node.
# 	node=1107 leaf node.
# 	node=1108 leaf node.
# 	node=1112 leaf node.
# 	node=1113 leaf node.
# 	node=1114 leaf node.
# 	node=1117 leaf node.
# 	node=1118 leaf node.
# 	node=1120 leaf node.
# 	node=1121 leaf node.
# 	node=1126 leaf node.
# 	node=1127 leaf node.
# 	node=1129 leaf node.
# 	node=1130 leaf node.
# 	node=1133 leaf node.
# 	node=1134 leaf node.
# 	node=1136 leaf node.
# 	node=1137 leaf node.
# 	node=1141 leaf node.
# 	node=1142 leaf node.
# 	node=1143 leaf node.
# 	node=1144 leaf node.
# 	node=1149 leaf node.
# 	node=1150 leaf node.
# 	node=1153 leaf node.
# 	node=1154 leaf node.
# 	node=1156 leaf node.
# 	node=1157 leaf node.
# 	node=1161 leaf node.
# 	node=1162 leaf node.
# 	node=1164 leaf node.
# 	node=1165 leaf node.
# 	node=1167 leaf node.
# 	node=1169 leaf node.
# 	node=1170 leaf node.
# 	node=1175 leaf node.
# 	node=1176 leaf node.
# 	node=1178 leaf node.
# 	node=1179 leaf node.
# 	node=1182 leaf node.
# 	node=1183 leaf node.
# 	node=1185 leaf node.
# 	node=1186 leaf node.
# 	node=1190 leaf node.
# 	node=1191 leaf node.
# 	node=1193 leaf node.
# 	node=1194 leaf node.
# 	node=1197 leaf node.
# 	node=1198 leaf node.
# 	node=1200 leaf node.
# 	node=1201 leaf node.
# 	node=1206 leaf node.
# 	node=1208 leaf node.
# 	node=1211 leaf node.
# 	node=1212 leaf node.
# 	node=1213 leaf node.
# 	node=1218 leaf node.
# 	node=1219 leaf node.
# 	node=1221 leaf node.
# 	node=1222 leaf node.
# 	node=1225 leaf node.
# 	node=1226 leaf node.
# 	node=1228 leaf node.
# 	node=1229 leaf node.
# 	node=1232 leaf node.
# 	node=1234 leaf node.
# 	node=1235 leaf node.
# 	node=1238 leaf node.
# 	node=1239 leaf node.
# 	node=1240 leaf node.
# 	node=1246 leaf node.
# 	node=1247 leaf node.
# 	node=1249 leaf node.
# 	node=1250 leaf node.
# 	node=1253 leaf node.
# 	node=1254 leaf node.
# 	node=1256 leaf node.
# 	node=1257 leaf node.
# 	node=1260 leaf node.
# 	node=1262 leaf node.
# 	node=1263 leaf node.
# 	node=1266 leaf node.
# 	node=1267 leaf node.
# 	node=1269 leaf node.
# 	node=1270 leaf node.
# 	node=1273 leaf node.
# 	node=1276 leaf node.
# 	node=1277 leaf node.
# 	node=1279 leaf node.
# 	node=1280 leaf node.
# 	node=1284 leaf node.
# 	node=1285 leaf node.
# 	node=1286 leaf node.
# 	node=1288 leaf node.
# 	node=1290 leaf node.
# 	node=1291 leaf node.
# 	node=1298 leaf node.
# 	node=1299 leaf node.
# 	node=1301 leaf node.
# 	node=1302 leaf node.
# 	node=1305 leaf node.
# 	node=1306 leaf node.
# 	node=1308 leaf node.
# 	node=1309 leaf node.
# 	node=1313 leaf node.
# 	node=1314 leaf node.
# 	node=1316 leaf node.
# 	node=1317 leaf node.
# 	node=1320 leaf node.
# 	node=1321 leaf node.
# 	node=1323 leaf node.
# 	node=1324 leaf node.
# 	node=1327 leaf node.
# 	node=1329 leaf node.
# 	node=1331 leaf node.
# 	node=1332 leaf node.
# 	node=1336 leaf node.
# 	node=1337 leaf node.
# 	node=1338 leaf node.
# 	node=1340 leaf node.
# 	node=1342 leaf node.
# 	node=1343 leaf node.
# 	node=1349 leaf node.
# 	node=1350 leaf node.
# 	node=1352 leaf node.
# 	node=1353 leaf node.
# 	node=1356 leaf node.
# 	node=1357 leaf node.
# 	node=1359 leaf node.
# 	node=1360 leaf node.
# 	node=1364 leaf node.
# 	node=1365 leaf node.
# 	node=1367 leaf node.
# 	node=1368 leaf node.
# 	node=1371 leaf node.
# 	node=1372 leaf node.
# 	node=1373 leaf node.
# 	node=1377 leaf node.
# 	node=1379 leaf node.
# 	node=1380 leaf node.
# 	node=1383 leaf node.
# 	node=1384 leaf node.
# 	node=1386 leaf node.
# 	node=1387 leaf node.
# 	node=1391 leaf node.
# 	node=1392 leaf node.
# 	node=1394 leaf node.
# 	node=1395 leaf node.
# 	node=1398 leaf node.
# 	node=1399 leaf node.
# 	node=1401 leaf node.
# 	node=1402 leaf node.
# 	node=1409 leaf node.
# 	node=1411 leaf node.
# 	node=1413 leaf node.
# 	node=1414 leaf node.
# 	node=1417 leaf node.
# 	node=1418 leaf node.
# 	node=1419 leaf node.
# 	node=1423 leaf node.
# 	node=1424 leaf node.
# 	node=1427 leaf node.
# 	node=1428 leaf node.
# 	node=1431 leaf node.
# 	node=1433 leaf node.
# 	node=1434 leaf node.
# 	node=1436 leaf node.
# 	node=1438 leaf node.
# 	node=1439 leaf node.
# 	node=1443 leaf node.
# 	node=1446 leaf node.
# 	node=1447 leaf node.
# 	node=1449 leaf node.
# 	node=1450 leaf node.
# 	node=1454 leaf node.
# 	node=1455 leaf node.
# 	node=1457 leaf node.
# 	node=1458 leaf node.
# 	node=1461 leaf node.
# 	node=1462 leaf node.
# 	node=1464 leaf node.
# 	node=1465 leaf node.
# 	node=1468 leaf node.
# 	node=1471 leaf node.
# 	node=1472 leaf node.
# 	node=1474 leaf node.
# 	node=1475 leaf node.
# 	node=1479 leaf node.
# 	node=1480 leaf node.
# 	node=1482 leaf node.
# 	node=1483 leaf node.
# 	node=1486 leaf node.
# 	node=1487 leaf node.
# 	node=1488 leaf node.
# 	node=1493 leaf node.
# 	node=1494 leaf node.
# 	node=1496 leaf node.
# 	node=1500 leaf node.
# 	node=1501 leaf node.
# 	node=1502 leaf node.
# 	node=1505 leaf node.
# 	node=1506 leaf node.
# 	node=1508 leaf node.
# 	node=1509 leaf node.
# 	node=1515 leaf node.
# 	node=1516 leaf node.
# 	node=1517 leaf node.
# 	node=1520 leaf node.
# 	node=1521 leaf node.
# 	node=1523 leaf node.
# 	node=1524 leaf node.
# 	node=1525 leaf node.
# 	node=1530 leaf node.
# 	node=1531 leaf node.
# 	node=1533 leaf node.
# 	node=1534 leaf node.
# 	node=1535 leaf node.
# 	node=1538 leaf node.
# 	node=1540 leaf node.
# 	node=1541 leaf node.
# 	node=1544 leaf node.
# 	node=1545 leaf node.
# 	node=1547 leaf node.
# 	node=1548 leaf node.
# 	node=1550 leaf node.
# 	node=1551 leaf node.
# 	node=1560 leaf node.
# 	node=1561 leaf node.
# 	node=1563 leaf node.
# 	node=1564 leaf node.
# 	node=1567 leaf node.
# 	node=1568 leaf node.
# 	node=1569 leaf node.
# 	node=1573 leaf node.
# 	node=1574 leaf node.
# 	node=1576 leaf node.
# 	node=1577 leaf node.
# 	node=1580 leaf node.
# 	node=1581 leaf node.
# 	node=1583 leaf node.
# 	node=1584 leaf node.
# 	node=1589 leaf node.
# 	node=1590 leaf node.
# 	node=1592 leaf node.
# 	node=1593 leaf node.
# 	node=1596 leaf node.
# 	node=1597 leaf node.
# 	node=1599 leaf node.
# 	node=1600 leaf node.
# 	node=1604 leaf node.
# 	node=1605 leaf node.
# 	node=1607 leaf node.
# 	node=1608 leaf node.
# 	node=1611 leaf node.
# 	node=1612 leaf node.
# 	node=1614 leaf node.
# 	node=1615 leaf node.
# 	node=1618 leaf node.
# 	node=1620 leaf node.
# 	node=1621 leaf node.
# 	node=1626 leaf node.
# 	node=1627 leaf node.
# 	node=1629 leaf node.
# 	node=1630 leaf node.
# 	node=1631 leaf node.
# 	node=1635 leaf node.
# 	node=1636 leaf node.
# 	node=1638 leaf node.
# 	node=1639 leaf node.
# 	node=1641 leaf node.
# 	node=1643 leaf node.
# 	node=1644 leaf node.
# 	node=1651 leaf node.
# 	node=1652 leaf node.
# 	node=1654 leaf node.
# 	node=1655 leaf node.
# 	node=1656 leaf node.
# 	node=1660 leaf node.
# 	node=1661 leaf node.
# 	node=1663 leaf node.
# 	node=1664 leaf node.
# 	node=1665 leaf node.
# 	node=1670 leaf node.
# 	node=1671 leaf node.
# 	node=1673 leaf node.
# 	node=1674 leaf node.
# 	node=1675 leaf node.
# 	node=1676 leaf node.
# 	node=1682 leaf node.
# 	node=1683 leaf node.
# 	node=1685 leaf node.
# 	node=1686 leaf node.
# 	node=1689 leaf node.
# 	node=1690 leaf node.
# 	node=1692 leaf node.
# 	node=1693 leaf node.
# 	node=1696 leaf node.
# 	node=1697 leaf node.
# 	node=1698 leaf node.
# 	node=1701 leaf node.
# 	node=1702 leaf node.
# 	node=1703 leaf node.
# 	node=1708 leaf node.
# 	node=1709 leaf node.
# 	node=1714 leaf node.
# 	node=1715 leaf node.
# 	node=1717 leaf node.
# 	node=1718 leaf node.
# 	node=1719 leaf node.
# 	node=1723 leaf node.
# 	node=1724 leaf node.
# 	node=1725 leaf node.
# 	node=1727 leaf node.
# 	node=1729 leaf node.
# 	node=1730 leaf node.
# 	node=1733 leaf node.
# 	node=1734 leaf node.
# 	node=1739 leaf node.
# 	node=1740 leaf node.
# 	node=1742 leaf node.
# 	node=1743 leaf node.
# 	node=1746 leaf node.
# 	node=1747 leaf node.
# 	node=1749 leaf node.
# 	node=1750 leaf node.
# 	node=1754 leaf node.
# 	node=1755 leaf node.
# 	node=1756 leaf node.
# 	node=1759 leaf node.
# 	node=1760 leaf node.
# 	node=1762 leaf node.
# 	node=1763 leaf node.
# 	node=1770 leaf node.
# 	node=1771 leaf node.
# 	node=1773 leaf node.
# 	node=1774 leaf node.
# 	node=1776 leaf node.
# 	node=1778 leaf node.
# 	node=1779 leaf node.
# 	node=1781 leaf node.
# 	node=1784 leaf node.
# 	node=1785 leaf node.
# 	node=1787 leaf node.
# 	node=1788 leaf node.
# 	node=1791 leaf node.
# 	node=1792 leaf node.
# 	node=1796 leaf node.
# 	node=1797 leaf node.
# 	node=1799 leaf node.
# 	node=1800 leaf node.
# 	node=1802 leaf node.
# 	node=1804 leaf node.
# 	node=1805 leaf node.
# 	node=1811 leaf node.
# 	node=1812 leaf node.
# 	node=1813 leaf node.
# 	node=1814 leaf node.
# 	node=1818 leaf node.
# 	node=1819 leaf node.
# 	node=1821 leaf node.
# 	node=1822 leaf node.
# 	node=1825 leaf node.
# 	node=1826 leaf node.
# 	node=1828 leaf node.
# 	node=1829 leaf node.
# 	node=1832 leaf node.
# 	node=1835 leaf node.
# 	node=1836 leaf node.
# 	node=1837 leaf node.
# 	node=1839 leaf node.
# 	node=1841 leaf node.
# 	node=1843 leaf node.
# 	node=1844 leaf node.
# 	node=1854 leaf node.
# 	node=1855 leaf node.
# 	node=1857 leaf node.
# 	node=1858 leaf node.
# 	node=1861 leaf node.
# 	node=1862 leaf node.
# 	node=1864 leaf node.
# 	node=1865 leaf node.
# 	node=1869 leaf node.
# 	node=1870 leaf node.
# 	node=1872 leaf node.
# 	node=1873 leaf node.
# 	node=1875 leaf node.
# 	node=1877 leaf node.
# 	node=1878 leaf node.
# 	node=1883 leaf node.
# 	node=1884 leaf node.
# 	node=1886 leaf node.
# 	node=1887 leaf node.
# 	node=1890 leaf node.
# 	node=1891 leaf node.
# 	node=1893 leaf node.
# 	node=1894 leaf node.
# 	node=1898 leaf node.
# 	node=1899 leaf node.
# 	node=1901 leaf node.
# 	node=1902 leaf node.
# 	node=1905 leaf node.
# 	node=1906 leaf node.
# 	node=1908 leaf node.
# 	node=1909 leaf node.
# 	node=1915 leaf node.
# 	node=1916 leaf node.
# 	node=1918 leaf node.
# 	node=1919 leaf node.
# 	node=1922 leaf node.
# 	node=1923 leaf node.
# 	node=1925 leaf node.
# 	node=1926 leaf node.
# 	node=1930 leaf node.
# 	node=1931 leaf node.
# 	node=1933 leaf node.
# 	node=1934 leaf node.
# 	node=1937 leaf node.
# 	node=1938 leaf node.
# 	node=1940 leaf node.
# 	node=1941 leaf node.
# 	node=1946 leaf node.
# 	node=1947 leaf node.
# 	node=1949 leaf node.
# 	node=1950 leaf node.
# 	node=1952 leaf node.
# 	node=1953 leaf node.
# 	node=1956 leaf node.
# 	node=1958 leaf node.
# 	node=1959 leaf node.
# 	node=1961 leaf node.
# 	node=1963 leaf node.
# 	node=1964 leaf node.
# 	node=1971 leaf node.
# 	node=1972 leaf node.
# 	node=1974 leaf node.
# 	node=1975 leaf node.
# 	node=1978 leaf node.
# 	node=1979 leaf node.
# 	node=1980 leaf node.
# 	node=1984 leaf node.
# 	node=1985 leaf node.
# 	node=1987 leaf node.
# 	node=1988 leaf node.
# 	node=1991 leaf node.
# 	node=1992 leaf node.
# 	node=1993 leaf node.
# 	node=1998 leaf node.
# 	node=1999 leaf node.
# 	node=2001 leaf node.
# 	node=2002 leaf node.
# 	node=2005 leaf node.
# 	node=2006 leaf node.
# 	node=2008 leaf node.
# 	node=2009 leaf node.
# 	node=2013 leaf node.
# 	node=2014 leaf node.
# 	node=2016 leaf node.
# 	node=2017 leaf node.
# 	node=2020 leaf node.
# 	node=2021 leaf node.
# 	node=2023 leaf node.
# 	node=2024 leaf node.
# 	node=2030 leaf node.
# 	node=2031 leaf node.
# 	node=2033 leaf node.
# 	node=2034 leaf node.
# 	node=2037 leaf node.
# 	node=2038 leaf node.
# 	node=2040 leaf node.
# 	node=2041 leaf node.
# 	node=2045 leaf node.
# 	node=2046 leaf node.
# 	node=2048 leaf node.
# 	node=2049 leaf node.
# 	node=2052 leaf node.
# 	node=2053 leaf node.
# 	node=2054 leaf node.
# 	node=2059 leaf node.
# 	node=2060 leaf node.
# 	node=2062 leaf node.
# 	node=2063 leaf node.
# 	node=2066 leaf node.
# 	node=2067 leaf node.
# 	node=2069 leaf node.
# 	node=2070 leaf node.
# 	node=2074 leaf node.
# 	node=2075 leaf node.
# 	node=2076 leaf node.
# 	node=2078 leaf node.
# 	node=2079 leaf node.
# 	node=2086 leaf node.
# 	node=2088 leaf node.
# 	node=2089 leaf node.
# 	node=2091 leaf node.
# 	node=2093 leaf node.
# 	node=2094 leaf node.
# 	node=2097 leaf node.
# 	node=2098 leaf node.
# 	node=2099 leaf node.
# 	node=2104 leaf node.
# 	node=2105 leaf node.
# 	node=2107 leaf node.
# 	node=2108 leaf node.
# 	node=2111 leaf node.
# 	node=2112 leaf node.
# 	node=2114 leaf node.
# 	node=2115 leaf node.
# 	node=2119 leaf node.
# 	node=2120 leaf node.
# 	node=2122 leaf node.
# 	node=2123 leaf node.
# 	node=2125 leaf node.
# 	node=2127 leaf node.
# 	node=2128 leaf node.
# 	node=2131 leaf node.
# 	node=2134 leaf node.
# 	node=2135 leaf node.
# 	node=2138 leaf node.
# 	node=2139 leaf node.
# 	node=2141 leaf node.
# 	node=2142 leaf node.
# 	node=2147 leaf node.
# 	node=2148 leaf node.
# 	node=2150 leaf node.
# 	node=2151 leaf node.
# 	node=2153 leaf node.
# 	node=2154 leaf node.
# 	node=2158 leaf node.
# 	node=2159 leaf node.
# 	node=2161 leaf node.
# 	node=2162 leaf node.
# 	node=2165 leaf node.
# 	node=2166 leaf node.
# 	node=2168 leaf node.
# 	node=2169 leaf node.
# 	node=2176 leaf node.
# 	node=2177 leaf node.
# 	node=2178 leaf node.
# 	node=2181 leaf node.
# 	node=2182 leaf node.
# 	node=2184 leaf node.
# 	node=2185 leaf node.
# 	node=2189 leaf node.
# 	node=2190 leaf node.
# 	node=2192 leaf node.
# 	node=2193 leaf node.
# 	node=2195 leaf node.
# 	node=2197 leaf node.
# 	node=2198 leaf node.
# 	node=2199 leaf node.
# 	node=2204 leaf node.
# 	node=2205 leaf node.
# 	node=2208 leaf node.
# 	node=2209 leaf node.
# 	node=2211 leaf node.
# 	node=2212 leaf node.
# 	node=2216 leaf node.
# 	node=2217 leaf node.
# 	node=2219 leaf node.
# 	node=2220 leaf node.
# 	node=2223 leaf node.
# 	node=2224 leaf node.
# 	node=2226 leaf node.
# 	node=2227 leaf node.
# 	node=2232 leaf node.
# 	node=2233 leaf node.
# 	node=2235 leaf node.
# 	node=2236 leaf node.
# 	node=2239 leaf node.
# 	node=2240 leaf node.
# 	node=2242 leaf node.
# 	node=2243 leaf node.
# 	node=2247 leaf node.
# 	node=2248 leaf node.
# 	node=2250 leaf node.
# 	node=2251 leaf node.
# 	node=2254 leaf node.
# 	node=2255 leaf node.
# 	node=2257 leaf node.
# 	node=2258 leaf node.
# 	node=2264 leaf node.
# 	node=2266 leaf node.
# 	node=2268 leaf node.
# 	node=2270 leaf node.
# 	node=2271 leaf node.
# 	node=2274 leaf node.
# 	node=2275 leaf node.
# 	node=2279 leaf node.
# 	node=2280 leaf node.
# 	node=2282 leaf node.
# 	node=2283 leaf node.
# 	node=2285 leaf node.
# 	node=2287 leaf node.
# 	node=2288 leaf node.
# 	node=2290 leaf node.
# 	node=2295 leaf node.
# 	node=2296 leaf node.
# 	node=2298 leaf node.
# 	node=2299 leaf node.
# 	node=2302 leaf node.
# 	node=2303 leaf node.
# 	node=2305 leaf node.
# 	node=2306 leaf node.
# 	node=2309 leaf node.
# 	node=2311 leaf node.
# 	node=2312 leaf node.
# 	node=2313 leaf node.
# 	node=2320 leaf node.
# 	node=2321 leaf node.
# 	node=2323 leaf node.
# 	node=2324 leaf node.
# 	node=2325 leaf node.
# 	node=2326 leaf node.
# 	node=2331 leaf node.
# 	node=2332 leaf node.
# 	node=2334 leaf node.
# 	node=2335 leaf node.
# 	node=2337 leaf node.
# 	node=2339 leaf node.
# 	node=2340 leaf node.
# 	node=2342 leaf node.
# 	node=2344 leaf node.
# 	node=2345 leaf node.
# 	node=2348 leaf node.
# 	node=2352 leaf node.
# 	node=2353 leaf node.
# 	node=2355 leaf node.
# 	node=2356 leaf node.
# 	node=2359 leaf node.
# 	node=2360 leaf node.
# 	node=2362 leaf node.
# 	node=2363 leaf node.
# 	node=2368 leaf node.
# 	node=2369 leaf node.
# 	node=2371 leaf node.
# 	node=2372 leaf node.
# 	node=2375 leaf node.
# 	node=2376 leaf node.
# 	node=2378 leaf node.
# 	node=2379 leaf node.
# 	node=2382 leaf node.
# 	node=2383 leaf node.
# 	node=2386 leaf node.
# 	node=2387 leaf node.
# 	node=2389 leaf node.
# 	node=2390 leaf node.
# 	node=2394 leaf node.
# 	node=2396 leaf node.
# 	node=2397 leaf node.
# 	node=2403 leaf node.
# 	node=2404 leaf node.
# 	node=2406 leaf node.
# 	node=2407 leaf node.
# 	node=2410 leaf node.
# 	node=2411 leaf node.
# 	node=2413 leaf node.
# 	node=2414 leaf node.
# 	node=2418 leaf node.
# 	node=2419 leaf node.
# 	node=2421 leaf node.
# 	node=2422 leaf node.
# 	node=2425 leaf node.
# 	node=2426 leaf node.
# 	node=2428 leaf node.
# 	node=2429 leaf node.
# 	node=2432 leaf node.
# 	node=2433 leaf node.
# 	node=2434 leaf node.
# 	node=2441 leaf node.
# 	node=2442 leaf node.
# 	node=2443 leaf node.
# 	node=2446 leaf node.
# 	node=2447 leaf node.
# 	node=2449 leaf node.
# 	node=2450 leaf node.
# 	node=2454 leaf node.
# 	node=2455 leaf node.
# 	node=2457 leaf node.
# 	node=2458 leaf node.
# 	node=2461 leaf node.
# 	node=2462 leaf node.
# 	node=2464 leaf node.
# 	node=2465 leaf node.
# 	node=2470 leaf node.
# 	node=2471 leaf node.
# 	node=2473 leaf node.
# 	node=2474 leaf node.
# 	node=2476 leaf node.
# 	node=2478 leaf node.
# 	node=2479 leaf node.
# 	node=2483 leaf node.
# 	node=2484 leaf node.
# 	node=2486 leaf node.
# 	node=2487 leaf node.
# 	node=2490 leaf node.
# 	node=2491 leaf node.
# 	node=2493 leaf node.
# 	node=2494 leaf node.
# 	node=2499 leaf node.
# 	node=2500 leaf node.
# 	node=2502 leaf node.
# 	node=2504 leaf node.
# 	node=2505 leaf node.
# 	node=2509 leaf node.
# 	node=2510 leaf node.
# 	node=2512 leaf node.
# 	node=2513 leaf node.
# 	node=2515 leaf node.
# 	node=2517 leaf node.
# 	node=2518 leaf node.
# 	node=2522 leaf node.
# 	node=2524 leaf node.
# 	node=2525 leaf node.
# 	node=2527 leaf node.
# 	node=2528 leaf node.
# 	node=2531 leaf node.
# 	node=2533 leaf node.
# 	node=2534 leaf node.
# 	node=2536 leaf node.
# 	node=2538 leaf node.
# 	node=2539 leaf node.
# 	node=2551 leaf node.
# 	node=2552 leaf node.
# 	node=2554 leaf node.
# 	node=2555 leaf node.
# 	node=2558 leaf node.
# 	node=2559 leaf node.
# 	node=2561 leaf node.
# 	node=2562 leaf node.
# 	node=2563 leaf node.
# 	node=2566 leaf node.
# 	node=2568 leaf node.
# 	node=2569 leaf node.
# 	node=2570 leaf node.
# 	node=2572 leaf node.
# 	node=2575 leaf node.
# 	node=2576 leaf node.
# 	node=2577 leaf node.
# 	node=2581 leaf node.
# 	node=2582 leaf node.
# 	node=2583 leaf node.
# 	node=2587 leaf node.
# 	node=2588 leaf node.
# 	node=2589 leaf node.
# 	node=2590 leaf node.
# 	node=2593 leaf node.
# 	node=2595 leaf node.
# 	node=2596 leaf node.
# 	node=2597 leaf node.
# 	node=2598 leaf node.
# 	node=2604 leaf node.
# 	node=2605 leaf node.
# 	node=2607 leaf node.
# 	node=2610 leaf node.
# 	node=2611 leaf node.
# 	node=2612 leaf node.
# 	node=2619 leaf node.
# 	node=2620 leaf node.
# 	node=2622 leaf node.
# 	node=2623 leaf node.
# 	node=2626 leaf node.
# 	node=2627 leaf node.
# 	node=2629 leaf node.
# 	node=2630 leaf node.
# 	node=2632 leaf node.
# 	node=2633 leaf node.
# 	node=2635 leaf node.
# 	node=2636 leaf node.
# 	node=2638 leaf node.
# 	node=2643 leaf node.
# 	node=2644 leaf node.
# 	node=2645 leaf node.
# 	node=2646 leaf node.
# 	node=2650 leaf node.
# 	node=2651 leaf node.
# 	node=2653 leaf node.
# 	node=2654 leaf node.
# 	node=2656 leaf node.
# 	node=2657 leaf node.
# 	node=2658 leaf node.
# 	node=2664 leaf node.
# 	node=2665 leaf node.
# 	node=2667 leaf node.
# 	node=2669 leaf node.
# 	node=2670 leaf node.
# 	node=2674 leaf node.
# 	node=2675 leaf node.
# 	node=2676 leaf node.
# 	node=2681 leaf node.
# 	node=2682 leaf node.
# 	node=2684 leaf node.
# 	node=2685 leaf node.
# 	node=2687 leaf node.
# 	node=2688 leaf node.
# 	node=2691 leaf node.
# 	node=2692 leaf node.
# 	node=2695 leaf node.
# 	node=2696 leaf node.
# 	node=2697 leaf node.
# 	node=2700 leaf node.
# 	node=2702 leaf node.
# 	node=2704 leaf node.
# 	node=2706 leaf node.
# 	node=2707 leaf node.
# 	node=2712 leaf node.
# 	node=2713 leaf node.
# 	node=2716 leaf node.
# 	node=2717 leaf node.
# 	node=2718 leaf node.
# 	node=2721 leaf node.
# 	node=2722 leaf node.
# 	node=2724 leaf node.
# 	node=2725 leaf node.
# 	node=2728 leaf node.
# 	node=2729 leaf node.
# 	node=2733 leaf node.
# 	node=2734 leaf node.
# 	node=2736 leaf node.
# 	node=2737 leaf node.
# 	node=2738 leaf node.
# 	node=2741 leaf node.
# 	node=2743 leaf node.
# 	node=2746 leaf node.
# 	node=2748 leaf node.
# 	node=2749 leaf node.
# 	node=2750 leaf node.
# 	node=2753 leaf node.
# 	node=2755 leaf node.
# 	node=2756 leaf node.
# 	node=2759 leaf node.
# 	node=2760 leaf node.
# 	node=2761 leaf node.
# 	node=2768 leaf node.
# 	node=2769 leaf node.
# 	node=2770 leaf node.
# 	node=2771 leaf node.
# 	node=2777 leaf node.
# 	node=2778 leaf node.
# 	node=2779 leaf node.
# 	node=2782 leaf node.
# 	node=2783 leaf node.
# 	node=2786 leaf node.
# 	node=2787 leaf node.
# 	node=2790 leaf node.
# 	node=2791 leaf node.
# 	node=2793 leaf node.
# 	node=2794 leaf node.
# 	node=2797 leaf node.
# 	node=2800 leaf node.
# 	node=2801 leaf node.
# 	node=2802 leaf node.
# 	node=2804 leaf node.
# 	node=2805 leaf node.
# 	node=2811 leaf node.
# 	node=2812 leaf node.
# 	node=2813 leaf node.
# 	node=2814 leaf node.
# 	node=2815 leaf node.
# 	node=2816 leaf node.
# 	node=2818 leaf node.
# 	node=2820 leaf node.
# 	node=2821 leaf node.
# 	node=2827 leaf node.
# 	node=2830 leaf node.
# 	node=2831 leaf node.
# 	node=2833 leaf node.
# 	node=2835 leaf node.
# 	node=2836 leaf node.
# 	node=2839 leaf node.
# 	node=2840 leaf node.
# 	node=2843 leaf node.
# 	node=2846 leaf node.
# 	node=2847 leaf node.
# 	node=2848 leaf node.
# 	node=2850 leaf node.
# 	node=2852 leaf node.
# 	node=2854 leaf node.
# 	node=2855 leaf node.
# 	node=2857 leaf node.
# 	node=2859 leaf node.
# 	node=2861 leaf node.
# 	node=2863 leaf node.
# 	node=2864 leaf node.
# 	node=2868 leaf node.
# 	node=2869 leaf node.
# 	node=2871 leaf node.
# 	node=2873 leaf node.
# 	node=2874 leaf node.
# 	node=2879 leaf node.
# 	node=2880 leaf node.
# 	node=2881 leaf node.
# 	node=2884 leaf node.
# 	node=2887 leaf node.
# 	node=2888 leaf node.
# 	node=2889 leaf node.
# 	node=2891 leaf node.
# 	node=2893 leaf node.
# 	node=2894 leaf node.
# 	node=2900 leaf node.
# 	node=2901 leaf node.
# 	node=2903 leaf node.
# 	node=2904 leaf node.
# 	node=2905 leaf node.
# 	node=2906 leaf node.
# 	node=2909 leaf node.
# 	node=2910 leaf node.
# 	node=2911 leaf node.
# 	node=2916 leaf node.
# 	node=2917 leaf node.
# 	node=2918 leaf node.
# 	node=2921 leaf node.
# 	node=2924 leaf node.
# 	node=2925 leaf node.
# 	node=2926 leaf node.
# 	node=2927 leaf node.
# 	node=2930 leaf node.
# 	node=2931 leaf node.
# 	node=2932 leaf node.
# ()

# %%
comp_list = ['P', 'He', 'Fe']
# comp_list = ['P', 'Fe']
# comp_list = le.inverse_transform(np.unique(y_test))

correctly_identified_mask = (test_predictions == y_test)

# Energy-related variables
energy_bin_width = 0.1
energy_bins = np.arange(6.2, 8.1, energy_bin_width)
# energy_bins = np.arange(6.2, 9.51, energy_bin_width)
energy_midpoints = (energy_bins[1:] + energy_bins[:-1]) / 2
log_energy = X_test[:, 0]

# Construct MC composition masks
MC_comp_mask = {}
for composition in comp_list:
    MC_comp_mask[composition] = (le.inverse_transform(y_test) == composition)

# Get number of MC comp in each reco energy bin
num_MC_energy, num_MC_energy_err = {}, {}
for composition in comp_list:
    num_MC_energy[composition] = np.histogram(log_energy[MC_comp_mask[composition]],
                                     bins=energy_bins)[0]
    num_MC_energy_err[composition] = np.sqrt(num_MC_energy[composition])

num_MC_energy['total'] = np.histogram(log_energy, bins=energy_bins)[0]
num_MC_energy_err['total'] = np.sqrt(num_MC_energy['total'])


# Get number of correctly identified comp in each reco energy bin
num_reco_energy, num_reco_energy_err = {}, {}
for composition in comp_list:
    num_reco_energy[composition] = np.histogram(
        log_energy[MC_comp_mask[composition] & correctly_identified_mask],
        bins=energy_bins)[0]
    num_reco_energy_err[composition] = np.sqrt(num_reco_energy[composition])

num_reco_energy['total'] = np.histogram(log_energy[correctly_identified_mask], bins=energy_bins)[0]
num_reco_energy_err['total'] = np.sqrt(num_reco_energy['total'])



# Calculate correctly identified fractions as a function of MC energy
reco_frac, reco_frac_err = {}, {}
for composition in comp_list:
    print(composition)
    reco_frac[composition], reco_frac_err[composition] = comp.ratio_error(
        num_reco_energy[composition], num_reco_energy_err[composition],
        num_MC_energy[composition], num_MC_energy_err[composition])
    
reco_frac['total'], reco_frac_err['total'] = comp.ratio_error(
        num_reco_energy['total'], num_reco_energy_err['total'],
        num_MC_energy['total'], num_MC_energy_err['total'])
# Out:
# P
# He
# Fe

# %%
# Plot fraction of events vs energy
fig, ax = plt.subplots()
for composition in comp_list:
    ebar = ax.errorbar(energy_midpoints, reco_frac[composition],
                yerr=reco_frac_err[composition],
                # xerr=energy_bin_width / 2,
                marker=None, markersize=5,
                alpha=0.8)
    step_x = energy_midpoints
    step_x = np.append(step_x[0]-energy_bin_width/2, step_x)
    step_x = np.append(step_x, step_x[-1]+energy_bin_width/2)
    step_y = reco_frac[composition]
    step_y = np.append(step_y[0], step_y)
    step_y = np.append(step_y, step_y[-1])
    ax.step(step_x, step_y, where='mid',
            marker=None, color=ebar[0].get_color(), linewidth=0.9,
            linestyle='-', label=composition, alpha=0.8)
ebar = ax.errorbar(energy_midpoints, reco_frac['total'],
                yerr=reco_frac_err['total'],
                # xerr=energy_bin_width / 2,
                marker=None, markersize=5,
                alpha=0.8)
ax.step(energy_midpoints, reco_frac['total'], where='mid', marker=None,
        color=ebar[0].get_color(), linewidth=0.9, label='Total', alpha=0.8)
plt.xlabel('$\log_{10}(E_{\mathrm{reco}}/\mathrm{GeV})$')
ax.set_ylabel('Fraction correctly identified')
ax.set_ylim([0.0, 1.0])
ax.set_xlim([6.2, 8.0])
# ax.set_xlim([6.2, 9.5])
plt.grid()
# leg = plt.legend(loc=3)
leg = plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=len(comp_list)+1, fancybox=False, shadow=False)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
# place a text box in upper left in axes coords
textstr = 'Training features: \n'
for i, label in enumerate(feature_labels):
    if (i == len(feature_labels)-1):
        textstr += '{}) '.format(i+1) + label
    else:
        textstr += '{}) '.format(i+1) + label + '\n'
# print(textstr)
props = dict(facecolor='white')
# ax.text(0.0, 0.0, textstr, transform=ax.transAxes, fontsize=8,
#         verticalalignment='top', bbox=props)
ax.text(1.025, 1.0, textstr, transform=ax.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
outfile = '/home/jbourbeau/public_html/figures/composition' + \
          '/fraction-reco-correct_vs_reco-energy_RF.png'
plt.savefig(outfile)
plt.show()

# %%
a = pd.DataFrame([np.sum(df.MC_comp == composition) for composition in comp_list],
                 index=comp_list, columns=['MC Compositions'])
print(a)
a.plot.pie(subplots=True, figsize=(4,4), legend=False, autopct='%.2f')
a = pd.DataFrame([np.sum(le.inverse_transform(test_predictions) == composition) for composition in comp_list], index=comp_list, columns=['after'])
print(a)
a.plot.pie(subplots=True, figsize=(2,2))
# Out:
#     MC Compositions
# P             38151
# He            39736
# Fe            39840
#     after
# P   10921
# He  11614
# Fe  12784
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1922f3d0>], dtype=object)

# %%
num_features = len(feature_list)
importances = pipeline.named_steps['classifier'].feature_importances_
indices = np.argsort(importances)[::-1]

fig, ax = plt.subplots()
# feature_labels = np.array(['$\\log_{10}({\mathrm{E/GeV})$', 'InIce charge',
#                            '$\cos(\\theta)$', '$\mathrm{Laputop}\ \chi^2/\mathrm{n.d.f.}$', 'NChannels'])
for f in range(num_features):
    print('{}) {}'.format(f + 1, importances[indices[f]]))

plt.ylabel('Feature Importances')
plt.bar(range(num_features),
        importances[indices],
        align='center')

plt.xticks(range(num_features),
           feature_labels[indices], rotation=90)
plt.xlim([-1, len(feature_list)])
# plt.ylim([0, .40])
plt.show()
# Out:
# 1) 0.33064538357
# 2) 0.187678165573
# 3) 0.174925540871
# 4) 0.159199898412
# 5) 0.147551011574

# %%
probs = pipeline.named_steps['classifier'].predict_proba(X_test)
prob_1 = probs[:, 0][MC_iron_mask]
prob_2 = probs[:, 1][MC_iron_mask]
# print(min(prob_1-prob_2))
# print(max(prob_1-prob_2))
# plt.hist(prob_1-prob_2, bins=30, log=True)
plt.hist(prob_1, bins=np.linspace(0, 1, 50), log=True)
plt.hist(prob_2, bins=np.linspace(0, 1, 50), log=True)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-50-b87560b6ea5f> in <module>()
#       1 probs = pipeline.named_steps['classifier'].predict_proba(X_test)
# ----> 2 prob_1 = probs[:, 0][MC_iron_mask]
#       3 prob_2 = probs[:, 1][MC_iron_mask]
#       4 # print(min(prob_1-prob_2))
#       5 # print(max(prob_1-prob_2))
#
# NameError: name 'MC_iron_mask' is not defined

# %%
probs = pipeline.named_steps['classifier'].predict_proba(X_test)
dp1 = (probs[:, 0]-probs[:, 1])[MC_proton_mask]
print(min(dp1))
print(max(dp1))
dp2 = (probs[:, 0]-probs[:, 1])[MC_iron_mask]
print(min(dp2))
print(max(dp2))
fig, ax = plt.subplots()
# plt.hist(prob_1-prob_2, bins=30, log=True)
counts, edges, pathes = plt.hist(dp1, bins=np.linspace(-1, 1, 100), log=True, label='Proton', alpha=0.75)
counts, edges, pathes = plt.hist(dp2, bins=np.linspace(-1, 1, 100), log=True, label='Iron', alpha=0.75)
plt.legend(loc=2)
plt.show()
pipeline.named_steps['classifier'].classes_

# %%
print(pipeline.named_steps['classifier'].classes_)
le.inverse_transform(pipeline.named_steps['classifier'].classes_)

# %%
pipeline.named_steps['classifier'].decision_path(X_test)
